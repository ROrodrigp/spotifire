# %%
import pandas as pd
import boto3
from io import BytesIO

# %%
# Configurar S3
# Definir la ruta exacta al archivo snappy.parquet
bucket_name = "itam-analytics-ragp"
parquet_key = "spotifire/processed/individual/user_12137259902.parquet/part-00000-45af4168-237b-4b78-ac7c-2cd1531b8e69-c000.snappy.parquet"
s3_client = boto3.client('s3')

# %%
# Descargar el archivo directamente
print(f"Descargando archivo: s3://{bucket_name}/{parquet_key}")
response = s3_client.get_object(Bucket=bucket_name, Key=parquet_key)
parquet_data = BytesIO(response['Body'].read())
# Out:
# Descargando archivo: s3://itam-analytics-ragp/spotifire/processed/individual/user_12137259902.parquet/part-00000-45af4168-237b-4b78-ac7c-2cd1531b8e69-c000.snappy.parquet

# %%
#  Leer el parquet con pandas
df = pd.read_parquet(parquet_data)

# %%
df.head()
# Out:
#        user_id           played_at_utc        played_at_mexico  \
# 0  12137259902 2025-05-13 20:35:52.827 2025-05-13 14:35:52.827
# 1  12137259902 2025-05-13 20:39:44.322 2025-05-13 14:39:44.322
# 2  12137259902 2025-05-14 22:47:18.484 2025-05-14 16:47:18.484
# 3  12137259902 2025-05-14 22:50:53.894 2025-05-14 16:50:53.894
# 4  12137259902 2025-05-14 22:53:46.693 2025-05-14 16:53:46.693
#
#                  track_id      track_name               artist_id  \
# 0  0WoFs3EdGOx58yX5BtXvOa       Your Love  1zxDewzd2j1ZdSBGaYcr0y
# 1  7zMUCLm1TN9o9JlLISztxO    Burning Love  43ZHCT0cAZBISjO8DG9PnE
# 2  3sK8wGT43QFpWrvNQsrQya            DtMF  4q3ewBCX7sLwd24euuV69X
# 3  29Ro9cW0qbFdXGmrJ3aNKs       Compartir  0XK6kT7xcZAlcYrNjOgzJe
# 4  0l0vcZMU7AOeQmUIREoI2U  Qué Pasaría...  1mcTU81TzQhprhouKaTkpq
#
#       artist_name                album_id            album_name  duration_ms  \
# 0    The Outfield  0EriQlp6zHpb1ThLZcandW             Play Deep       216466
# 1   Elvis Presley  3gpHiNAmT5oXVxe6ewTGuN          Elvis (Fool)       170293
# 2       Bad Bunny  5K79FLRUCSysQnVESLcTdb  DeBÍ TiRAR MáS FOToS       237117
# 3  Carla Morrison  2dXJG8zygelhXXvQuKn4Ye   Mientras Tú Dormías       257091
# 4  Rauw Alejandro  0aX0UXrHG2ceYIxTQcqJdA          Cosa Nuestra       191018
#
#    duration_minutes  popularity  explicit  play_hour  play_day_of_week  \
# 0              3.61          82     False         14                 3
# 1              2.84          78     False         14                 3
# 2              3.95          97      True         16                 4
# 3              4.28          72     False         16                 4
# 4              3.18          91      True         16                 4
#
#    play_month  play_year  season            processed_at
# 0           5       2025  Spring 2025-05-20 04:27:10.354
# 1           5       2025  Spring 2025-05-20 04:27:10.354
# 2           5       2025  Spring 2025-05-20 04:27:10.354
# 3           5       2025  Spring 2025-05-20 04:27:10.354
# 4           5       2025  Spring 2025-05-20 04:27:10.354

# %%
df['artist_name'].value_counts()
# Out:
# artist_name
# Grupo Marca Registrada                           10
# Fobia                                             7
# León Larregui                                     7
# Bad Bunny                                         5
# Carín León                                        5
# Julión Álvarez y su Norteño Banda                 5
# Eden Muñoz                                        4
# La Arrolladora Banda El Limón De Rene Camacho     4
# Calibre 50                                        4
# Caloncho                                          3
# Zoé                                               3
# Caifanes                                          3
# Rauw Alejandro                                    3
# Meme del Real                                     2
# Los Bunkers                                       2
# Fuerza Regida                                     2
# Maná                                              2
# Grupo Frontera                                    1
# La Adictiva                                       1
# Belanova                                          1
# Piso 21                                           1
# Ozuna                                             1
# Gabito Ballesteros                                1
# Joan Sebastian                                    1
# Ed Maverick                                       1
# The Outfield                                      1
# Peso Pluma                                        1
# Michelle Maciel                                   1
# Elvis Presley                                     1
# Motel                                             1
# Plastilina Mosh                                   1
# Mikel Erentxun                                    1
# Guns N' Roses                                     1
# Carla Morrison                                    1
# Bobby Pulido                                      1
# Name: count, dtype: int64

# %%
df['play_hour'].value_counts()
# Out:
# play_hour
# 14    17
# 21    17
# 17    15
# 13    15
# 16    10
# 11     4
# 12     4
# 15     2
# 10     2
# 22     2
# 20     1
# Name: count, dtype: int64

# %%
df.tail()
# Out:
#         user_id           played_at_utc        played_at_mexico  \
# 84  12137259902 2025-05-19 03:48:59.638 2025-05-18 21:48:59.638
# 85  12137259902 2025-05-19 03:52:47.212 2025-05-18 21:52:47.212
# 86  12137259902 2025-05-19 03:56:19.999 2025-05-18 21:56:19.999
# 87  12137259902 2025-05-19 04:00:17.980 2025-05-18 22:00:17.980
# 88  12137259902 2025-05-19 04:04:22.597 2025-05-18 22:04:22.597
#
#                   track_id            track_name               artist_id  \
# 84  1uGUbgZuO1kD1JZ0UeFupN          Hecha Pa' Mí  6XkjpgcEsYab502Vr1bBeW
# 85  2JJSGhPpATm8lXeYjD95fw             Desvelado  4EEZg8R3dxbTCCQ1DVWtHg
# 86  4Ndjd6DhKIC5IPoBIrMQuX  Ese Vato No Te Queda  66ihevNkSYNzRAl44dx6jJ
# 87  3sK8wGT43QFpWrvNQsrQya                  DtMF  4q3ewBCX7sLwd24euuV69X
# 88  3D24ErT1MMmUfXWotSj2A2               ME JALO  0ys2OFYzWYB5hRDLCsBqxt
#
#        artist_name                album_id            album_name  duration_ms  \
# 84  Grupo Frontera  3Z9jjBDBjKUkf7CXPm5aSF          Hecha Pa' Mí       195845
# 85    Bobby Pulido  2BCS2taG5BuYeL3QPCbcz2             Desvelado       221226
# 86      Carín León  4Z9Ib007Z7ZFmYLfyp2qH9  Ese Vato No Te Queda       198607
# 87       Bad Bunny  5K79FLRUCSysQnVESLcTdb  DeBÍ TiRAR MáS FOToS       237117
# 88   Fuerza Regida  5utxE1ImIDJFXRHf137hoy              MALA MÍA       212002
#
#     duration_minutes  popularity  explicit  play_hour  play_day_of_week  \
# 84              3.26          82     False         21                 1
# 85              3.69          77     False         21                 1
# 86              3.31          82      True         21                 1
# 87              3.95          98      True         22                 1
# 88              3.53          92      True         22                 1
#
#     play_month  play_year  season            processed_at
# 84           5       2025  Spring 2025-05-20 04:27:10.354
# 85           5       2025  Spring 2025-05-20 04:27:10.354
# 86           5       2025  Spring 2025-05-20 04:27:10.354
# 87           5       2025  Spring 2025-05-20 04:27:10.354
# 88           5       2025  Spring 2025-05-20 04:27:10.354

# %%
# Mostrar algunos análisis básicos
print("\nTop 5 artistas más escuchados:")
print(df['artist_name'].value_counts().head(5))
# Out:
# Top 5 artistas más escuchados:
# artist_name
# Grupo Marca Registrada    10
# Fobia                      7
# León Larregui              7
# Bad Bunny                  5
# Carín León                 5
# Name: count, dtype: int64

# %%
print("\nEstadísticas descriptivas:")
print(df.describe())
# Out:
# Estadísticas descriptivas:
#                        played_at_utc               played_at_mexico  \
# count                             89                             89
# mean   2025-05-16 08:18:53.500808704  2025-05-16 02:18:53.500808960
# min       2025-05-13 20:35:52.827000     2025-05-13 14:35:52.827000
# 25%       2025-05-15 03:00:36.668000     2025-05-14 21:00:36.668000
# 50%    2025-05-15 19:58:08.440999936  2025-05-15 13:58:08.440999936
# 75%    2025-05-16 22:29:22.921999872  2025-05-16 16:29:22.921999872
# max       2025-05-19 04:04:22.597000     2025-05-18 22:04:22.597000
# std                              NaN                            NaN
#
#          duration_ms  duration_minutes  popularity  play_hour  \
# count      89.000000         89.000000   89.000000  89.000000
# mean   217156.932584          3.619438   73.235955  15.853933
# min    126081.000000          2.100000   31.000000  10.000000
# 25%    175532.000000          2.930000   68.000000  13.000000
# 50%    212226.000000          3.540000   76.000000  16.000000
# 75%    241648.000000          4.030000   81.000000  17.000000
# max    367725.000000          6.130000   98.000000  22.000000
# std     48444.879032          0.807474   13.700549   3.315085
#
#        play_day_of_week  play_month  play_year                   processed_at
# count         89.000000        89.0       89.0                             89
# mean           4.550562         5.0     2025.0  2025-05-20 04:27:10.354000128
# min            1.000000         5.0     2025.0     2025-05-20 04:27:10.354000
# 25%            4.000000         5.0     2025.0  2025-05-20 04:27:10.353999872
# 50%            5.000000         5.0     2025.0  2025-05-20 04:27:10.353999872
# 75%            6.000000         5.0     2025.0  2025-05-20 04:27:10.353999872
# max            7.000000         5.0     2025.0     2025-05-20 04:27:10.354000
# std            1.699005         0.0        0.0                            NaN

# %%
print("\nInformación de tipos de datos:")
print(df.info())
# Out:
# Información de tipos de datos:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           89 non-null     object
#  1   played_at_utc     89 non-null     datetime64[ns]
#  2   played_at_mexico  89 non-null     datetime64[ns]
#  3   track_id          89 non-null     object
#  4   track_name        89 non-null     object
#  5   artist_id         89 non-null     object
#  6   artist_name       89 non-null     object
#  7   album_id          89 non-null     object
#  8   album_name        89 non-null     object
#  9   duration_ms       89 non-null     int32
#  10  duration_minutes  89 non-null     float64
#  11  popularity        89 non-null     int32
#  12  explicit          89 non-null     bool
#  13  play_hour         89 non-null     int32
#  14  play_day_of_week  89 non-null     int32
#  15  play_month        89 non-null     int32
#  16  play_year         89 non-null     int32
#  17  season            89 non-null     object
#  18  processed_at      89 non-null     datetime64[ns]
# dtypes: bool(1), datetime64[ns](3), float64(1), int32(6), object(8)
# memory usage: 10.6+ KB
# None
