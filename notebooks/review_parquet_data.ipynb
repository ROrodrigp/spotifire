# %%
import pandas as pd
import boto3
from io import BytesIO

# %%
# Configurar S3
# Definir la ruta exacta al archivo snappy.parquet
bucket_name = "itam-analytics-ragp"
parquet_key = "spotifire/processed/individual/user_12137259902.parquet/part-00000-6fe9deb7-e1b7-4a92-8705-e3c94ef388cd-c000.snappy.parquet"
s3_client = boto3.client('s3')

# %%
# Descargar el archivo directamente
print(f"Descargando archivo: s3://{bucket_name}/{parquet_key}")
response = s3_client.get_object(Bucket=bucket_name, Key=parquet_key)
parquet_data = BytesIO(response['Body'].read())
# Out:
# Descargando archivo: s3://itam-analytics-ragp/spotifire/processed/individual/user_12137259902.parquet/part-00000-6fe9deb7-e1b7-4a92-8705-e3c94ef388cd-c000.snappy.parquet

# %%
#  Leer el parquet con pandas
df = pd.read_parquet(parquet_data)

# %%
df.head()
# Out:
#        user_id           played_at_utc        played_at_mexico  \
# 0  12137259902 2025-05-13 20:35:52.827 2025-05-13 14:35:52.827
# 1  12137259902 2025-05-13 20:39:44.322 2025-05-13 14:39:44.322
# 2  12137259902 2025-05-14 22:47:18.484 2025-05-14 16:47:18.484
# 3  12137259902 2025-05-14 22:50:53.894 2025-05-14 16:50:53.894
# 4  12137259902 2025-05-14 22:53:46.693 2025-05-14 16:53:46.693
#
#                  track_id      track_name               artist_id  \
# 0  0WoFs3EdGOx58yX5BtXvOa       Your Love  1zxDewzd2j1ZdSBGaYcr0y
# 1  7zMUCLm1TN9o9JlLISztxO    Burning Love  43ZHCT0cAZBISjO8DG9PnE
# 2  3sK8wGT43QFpWrvNQsrQya            DtMF  4q3ewBCX7sLwd24euuV69X
# 3  29Ro9cW0qbFdXGmrJ3aNKs       Compartir  0XK6kT7xcZAlcYrNjOgzJe
# 4  0l0vcZMU7AOeQmUIREoI2U  Qué Pasaría...  1mcTU81TzQhprhouKaTkpq
#
#       artist_name                album_id            album_name  duration_ms  \
# 0    The Outfield  0EriQlp6zHpb1ThLZcandW             Play Deep       216466
# ...

# %%
df['artist_name'].value_counts()
# Out:
# artist_name
# León Larregui                                    12
# Grupo Marca Registrada                           10
# Carín León                                        8
# Julión Álvarez y su Norteño Banda                 7
# Fobia                                             7
# Zoé                                               7
# Bad Bunny                                         6
# La Arrolladora Banda El Limón De Rene Camacho     5
# Caloncho                                          5
# Los Bunkers                                       5
# Sabrina Carpenter                                 4
# Calibre 50                                        4
# Fuerza Regida                                     4
# Eden Muñoz                                        4
# Meme del Real                                     4
# Rauw Alejandro                                    4
# Caifanes                                          4
# Maná                                              3
# ...

# %%
df['artist_name'].value_counts()
# Out:
# artist_name
# León Larregui                                    12
# Grupo Marca Registrada                           10
# Carín León                                        8
# Julión Álvarez y su Norteño Banda                 7
# Fobia                                             7
# Zoé                                               7
# Bad Bunny                                         6
# La Arrolladora Banda El Limón De Rene Camacho     5
# Caloncho                                          5
# Los Bunkers                                       5
# Sabrina Carpenter                                 4
# Calibre 50                                        4
# Fuerza Regida                                     4
# Eden Muñoz                                        4
# Meme del Real                                     4
# Rauw Alejandro                                    4
# Caifanes                                          4
# Maná                                              3
# ...

# %%
df['play_hour'].value_counts()
# Out:
# play_hour
# 13    42
# 14    31
# 21    17
# 17    15
# 12    11
# 16    10
# 19    10
# 20     7
# 11     4
# 15     2
# 10     2
# 22     2
# Name: count, dtype: int64

# %%
df.tail()
# Out:
#          user_id           played_at_utc        played_at_mexico  \
# 148  12137259902 2025-05-22 19:52:03.576 2025-05-22 13:52:03.576
# 149  12137259902 2025-05-22 19:57:37.792 2025-05-22 13:57:37.792
# 150  12137259902 2025-05-22 20:01:17.090 2025-05-22 14:01:17.090
# 151  12137259902 2025-05-22 20:05:49.024 2025-05-22 14:05:49.024
# 152  12137259902 2025-05-22 20:09:47.890 2025-05-22 14:09:47.890
#
#                    track_id                                       track_name  \
# 148  2pb0aDEgDJ3PfWW1clmvSS                                         Souvenir
# 149  6w6EINTodc8j0TWtrWHdm2  La mujer que bota fuego (feat. Natalia Jiménez)
# 150  0DgAhXlnF4UKBUvJUG0oJs                                         Ven Aquí
# 151  2Ye3wsl794JOx6Miklej48                                 amantes y amigos
# 152  2Ye3wsl794JOx6Miklej48                                 amantes y amigos
#
#                   artist_id     artist_name                album_id  \
# ...

# %%
# Mostrar algunos análisis básicos
print("\nTop 5 artistas más escuchados:")
print(df['artist_name'].value_counts().head(5))
# Out:
# Top 5 artistas más escuchados:
# artist_name
# Grupo Marca Registrada    10
# Fobia                      7
# León Larregui              7
# Bad Bunny                  5
# Carín León                 5
# Name: count, dtype: int64

# %%
print("\nEstadísticas descriptivas:")
print(df.describe())
# Out:
# Estadísticas descriptivas:
#                        played_at_utc               played_at_mexico  \
# count                             89                             89
# mean   2025-05-16 08:18:53.500808704  2025-05-16 02:18:53.500808960
# min       2025-05-13 20:35:52.827000     2025-05-13 14:35:52.827000
# 25%       2025-05-15 03:00:36.668000     2025-05-14 21:00:36.668000
# 50%    2025-05-15 19:58:08.440999936  2025-05-15 13:58:08.440999936
# 75%    2025-05-16 22:29:22.921999872  2025-05-16 16:29:22.921999872
# max       2025-05-19 04:04:22.597000     2025-05-18 22:04:22.597000
# std                              NaN                            NaN
#
#          duration_ms  duration_minutes  popularity  play_hour  \
# count      89.000000         89.000000   89.000000  89.000000
# mean   217156.932584          3.619438   73.235955  15.853933
# min    126081.000000          2.100000   31.000000  10.000000
# 25%    175532.000000          2.930000   68.000000  13.000000
# ...

# %%
print("\nInformación de tipos de datos:")
print(df.info())
# Out:
# Información de tipos de datos:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           153 non-null    object
#  1   played_at_utc     153 non-null    datetime64[ns]
#  2   played_at_mexico  153 non-null    datetime64[ns]
#  3   track_id          153 non-null    object
#  4   track_name        153 non-null    object
#  5   artist_id         153 non-null    object
#  6   artist_name       153 non-null    object
#  7   album_id          153 non-null    object
#  8   album_name        153 non-null    object
#  9   duration_ms       153 non-null    int32
#  10  duration_minutes  153 non-null    float64
#  11  popularity        153 non-null    int32
#  12  explicit          153 non-null    bool
#  13  play_hour         153 non-null    int32
#  14  play_day_of_week  153 non-null    int32
# ...
